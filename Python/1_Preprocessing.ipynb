# %%
# Preprocessing
# Haifaa Alzahrani
29/10/2020

# Import packages
import math
import pandas as pd # For DataFrame 
import numpy as np # Array and numerical processing

# %%
# Loading csv
dataset1 = pd.read_csv("~/MISK_DSI/R/DS_Research_GoodreadsBooks/Data/books.csv")
dataset1.info()
dataset1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11123 entries, 0 to 11122
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              11123 non-null  int64
#  1   title               11123 non-null  object
#  2   authors             11123 non-null  object
#  3   average_rating      11123 non-null  float64
#  4   isbn                11123 non-null  object
#  5   isbn13              11123 non-null  int64
#  6   language_code       11123 non-null  object
#  7     num_pages         11123 non-null  int64
#  8   ratings_count       11123 non-null  int64
#  9   text_reviews_count  11123 non-null  int64
#  10  publication_date    11123 non-null  object
#  11  publisher           11123 non-null  object
#  12  Unnamed: 12         0 non-null      float64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 1.1+ MB
#    bookID                                              title  \
# 0   44012                       Shield of Thunder (Troy  #2)
# 1    4315                                               Zaat
# 2    2819         A Circle of Quiet (Crosswicks Journals #1)
# 3    4451  People of the Lie: The Hope for Healing Human ...
# 4    5327                                  A Christmas Carol
#
#                                              authors  average_rating  \
# 0                                      David Gemmell            4.36
# 1  Sonallah Ibrahim/صنع الله إبراهيم/Anthony Cald...            3.55
# 2                                  Madeleine L'Engle            4.21
# 3                                      M. Scott Peck            3.98
# 4                         Charles Dickens/P.J. Lynch            4.05
#
#          isbn         isbn13 language_code    num_pages  ratings_count  \
# 0   345477014  9780345477019           ale          512            102
# 1  9774248449  9789774248443           ara          349            122
# 2    62545035  9780062545039         en-CA          246           5236
# 3   684848597  9780684848594         en-CA          272           6256
# 4   763631205  9780763631208         en-CA          160           4359
#
#    text_reviews_count publication_date                           publisher  \
# 0                  16        3/27/2007                    Ballantine Books
# 1                  12        3/15/2004  American University in Cairo Press
# 2                 506         1/1/1984                           HarperOne
# 3                 459         1/2/1998                          Touchstone
# 4                 353        9/12/2006                    Candlewick Press
#
#    Unnamed: 12
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
dataset2 = pd.read_csv("~/MISK_DSI/R/DS_Research_GoodreadsBooks/Data/goodreads_books.csv")
dataset2.info()
dataset2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52199 entries, 0 to 52198
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      52199 non-null  int64
#  1   title                   52199 non-null  object
#  2   link                    52199 non-null  object
#  3   series                  23319 non-null  object
#  4   cover_link              51592 non-null  object
#  5   author                  52199 non-null  object
#  6   author_link             52199 non-null  object
#  7   rating_count            52199 non-null  int64
#  8   review_count            52199 non-null  int64
#  9   average_rating          52199 non-null  float64
#  10  five_star_ratings       52199 non-null  int64
#  11  four_star_ratings       52199 non-null  int64
#  12  three_star_ratings      52199 non-null  int64
#  13  two_star_ratings        52199 non-null  int64
#  14  one_star_ratings        52199 non-null  int64
#  15  number_of_pages         49869 non-null  float64
#  16  date_published          51339 non-null  object
#  17  publisher               48563 non-null  object
#  18  original_title          39250 non-null  object
#  19  genre_and_votes         49359 non-null  object
#  20  isbn                    40316 non-null  object
#  21  isbn13                  39507 non-null  object
#  22  asin                    5236 non-null   object
#  23  settings                11515 non-null  object
#  24  characters              13695 non-null  object
#  25  awards                  10626 non-null  object
#  26  amazon_redirect_link    52199 non-null  object
#  27  worldcat_redirect_link  48214 non-null  object
#  28  recommended_books       48205 non-null  object
#  29  books_in_series         22078 non-null  object
#  30  description             49624 non-null  object
# dtypes: float64(2), int64(8), object(21)
# memory usage: 12.3+ MB
#         id                                              title  \
# 0   630104                                       Inner Circle
# 1     9487                                  A Time to Embrace
# 2  6050894                                           Take Two
# 3    39030                                          Reliquary
# 4      998  The Millionaire Next Door: The Surprising Secr...
#
#                                                 link               series  \
# 0  https://www.goodreads.com//book/show/630104.In...         (Private #5)
# 1  https://www.goodreads.com//book/show/9487.A_Ti...   (Timeless Love #2)
# 2  https://www.goodreads.com//book/show/6050894-t...  (Above the Line #2)
# 3  https://www.goodreads.com//book/show/39030.Rel...      (Pendergast #2)
# 4  https://www.goodreads.com//book/show/998.The_M...                  NaN
#
#                                           cover_link  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...
# 1  https://i.gr-assets.com/images/S/compressed.ph...
# 2  https://i.gr-assets.com/images/S/compressed.ph...
# 3  https://i.gr-assets.com/images/S/compressed.ph...
# 4  https://i.gr-assets.com/images/S/compressed.ph...
#
#                                 author  \
# 0            Kate Brian, Julian Peploe
# 1                      Karen Kingsbury
# 2                      Karen Kingsbury
# 3       Douglas Preston, Lincoln Child
# 4  Thomas J. Stanley, William D. Danko
#
#                                          author_link  rating_count  \
# 0  https://www.goodreads.com/author/show/94091.Ka...          7597
# 1  https://www.goodreads.com/author/show/3159984....          4179
# 2  https://www.goodreads.com/author/show/3159984....          6288
# 3  https://www.goodreads.com/author/show/12577.Do...         38382
# 4  https://www.goodreads.com/author/show/659.Thom...         72168
#
#    review_count  average_rating  ...         isbn13  asin  \
# 0           196            4.03  ...  9781416950417   NaN
# 1           177            4.35  ...  9781595542328   NaN
# 2           218            4.23  ...            NaN   NaN
# 3          1424            4.01  ...  9780765354952   NaN
# 4          3217            4.04  ...  9780671015206   NaN
#
#                                             settings  \
# 0                                                NaN
# 1                                                NaN
# 2                Bloomington, Indiana(United States)
# 3  New York State(United States) New York City, N...
# 4                                                NaN
#
#                                           characters  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Aloysius X.L. Pendergast, Margo Green, William...
# 4                                                NaN
#
#                                               awards  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Independent Publisher Book Award (IPPY) Nomine...
#
#                                 amazon_redirect_link  \
# 0  https://www.goodreads.com//book_link/follow/17...
# 1  https://www.goodreads.com//book_link/follow/17...
# 2  https://www.goodreads.com//book_link/follow/17...
# 3  https://www.goodreads.com//book_link/follow/17...
# 4  https://www.goodreads.com//book_link/follow/17...
#
#                               worldcat_redirect_link  \
# 0  https://www.goodreads.com//book_link/follow/8?...
# 1  https://www.goodreads.com//book_link/follow/8?...
# 2  https://www.goodreads.com//book_link/follow/8?...
# 3  https://www.goodreads.com//book_link/follow/8?...
# 4  https://www.goodreads.com//book_link/follow/8?...
#
#                                    recommended_books  \
# 0  726458, 726458, 1537534, 3047848, 1651302, 304...
# 1  127352, 127352, 40642197, 127353, 127354, 3891...
# 2  706250, 706250, 666481, 11942636, 706241, 1273...
# 3  39026, 39026, 11007668, 3986318, 51887330, 194...
# 4  1052, 1052, 763362, 69571, 78427, 30186948, 10...
#
#                                      books_in_series  \
# 0  381489, 381501, 352428, 630103, 1783281, 17832...
# 1                                             115036
# 2                         4010795, 40792877, 7306261
# 3  67035, 39031, 39033, 136637, 136638, 30068, 39...
# 4                                                NaN
#
#                                          description
# 0  Reed Brennan arrived at Easton Academy expecti...
# 1  Ideje az Ã¶lelÃ©snek TÃ¶rtÃ©net a remÃ©nyrÅl,...
# 2  Filmmakers Chase Ryan and Keith Ellison have c...
# 3                                                NaN
# 4  The incredible national bestseller that is cha...
#
# [5 rows x 31 columns]

# %%
# Removing unwanted columns and observations
dataset1.info()
dataset2.info()

# Remove empties
dataset1.dropna(axis=1, how='all')
dataset2.dropna(axis=0, how='all')
dataset1.dropna(axis=1, how='all')
dataset2.dropna(axis=0, how='all')

# Remove duplicated observations or books with no isbn
dataset1.drop_duplicates(keep=False, inplace=True) # was 11,131 rows - became 11,123 rows
dataset2.drop_duplicates(keep=False, inplace=True) # was 52199 rows - became 40317 rows

# Remove unwanted columns
dataset1 = dataset1.drop('isbn13', axis = 1)
dataset2 = dataset2.drop('isbn13', axis = 1)

dataset1.info()
dataset2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11123 entries, 0 to 11122
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              11123 non-null  int64
#  1   title               11123 non-null  object
#  2   authors             11123 non-null  object
#  3   average_rating      11123 non-null  float64
#  4   isbn                11123 non-null  object
#  5   isbn13              11123 non-null  int64
#  6   language_code       11123 non-null  object
#  7     num_pages         11123 non-null  int64
#  8   ratings_count       11123 non-null  int64
#  9   text_reviews_count  11123 non-null  int64
#  10  publication_date    11123 non-null  object
#  11  publisher           11123 non-null  object
#  12  Unnamed: 12         0 non-null      float64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 1.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52199 entries, 0 to 52198
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      52199 non-null  int64
#  1   title                   52199 non-null  object
#  2   link                    52199 non-null  object
#  3   series                  23319 non-null  object
#  4   cover_link              51592 non-null  object
#  5   author                  52199 non-null  object
#  6   author_link             52199 non-null  object
#  7   rating_count            52199 non-null  int64
#  8   review_count            52199 non-null  int64
#  9   average_rating          52199 non-null  float64
#  10  five_star_ratings       52199 non-null  int64
#  11  four_star_ratings       52199 non-null  int64
#  12  three_star_ratings      52199 non-null  int64
#  13  two_star_ratings        52199 non-null  int64
#  14  one_star_ratings        52199 non-null  int64
#  15  number_of_pages         49869 non-null  float64
#  16  date_published          51339 non-null  object
#  17  publisher               48563 non-null  object
#  18  original_title          39250 non-null  object
#  19  genre_and_votes         49359 non-null  object
#  20  isbn                    40316 non-null  object
#  21  isbn13                  39507 non-null  object
#  22  asin                    5236 non-null   object
#  23  settings                11515 non-null  object
#  24  characters              13695 non-null  object
#  25  awards                  10626 non-null  object
#  26  amazon_redirect_link    52199 non-null  object
#  27  worldcat_redirect_link  48214 non-null  object
#  28  recommended_books       48205 non-null  object
#  29  books_in_series         22078 non-null  object
#  30  description             49624 non-null  object
# dtypes: float64(2), int64(8), object(21)
# memory usage: 12.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11123 entries, 0 to 11122
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              11123 non-null  int64
#  1   title               11123 non-null  object
#  2   authors             11123 non-null  object
#  3   average_rating      11123 non-null  float64
#  4   isbn                11123 non-null  object
#  5   language_code       11123 non-null  object
#  6     num_pages         11123 non-null  int64
#  7   ratings_count       11123 non-null  int64
#  8   text_reviews_count  11123 non-null  int64
#  9   publication_date    11123 non-null  object
#  10  publisher           11123 non-null  object
#  11  Unnamed: 12         0 non-null      float64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 1.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52199 entries, 0 to 52198
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      52199 non-null  int64
#  1   title                   52199 non-null  object
#  2   link                    52199 non-null  object
#  3   series                  23319 non-null  object
#  4   cover_link              51592 non-null  object
#  5   author                  52199 non-null  object
#  6   author_link             52199 non-null  object
#  7   rating_count            52199 non-null  int64
#  8   review_count            52199 non-null  int64
#  9   average_rating          52199 non-null  float64
#  10  five_star_ratings       52199 non-null  int64
#  11  four_star_ratings       52199 non-null  int64
#  12  three_star_ratings      52199 non-null  int64
#  13  two_star_ratings        52199 non-null  int64
#  14  one_star_ratings        52199 non-null  int64
#  15  number_of_pages         49869 non-null  float64
#  16  date_published          51339 non-null  object
#  17  publisher               48563 non-null  object
#  18  original_title          39250 non-null  object
#  19  genre_and_votes         49359 non-null  object
#  20  isbn                    40316 non-null  object
#  21  asin                    5236 non-null   object
#  22  settings                11515 non-null  object
#  23  characters              13695 non-null  object
#  24  awards                  10626 non-null  object
#  25  amazon_redirect_link    52199 non-null  object
#  26  worldcat_redirect_link  48214 non-null  object
#  27  recommended_books       48205 non-null  object
#  28  books_in_series         22078 non-null  object
#  29  description             49624 non-null  object
# dtypes: float64(2), int64(8), object(20)
# memory usage: 12.3+ MB

# %%
# Format publication date to only include the year
dataset1['publication_date'] = dataset1['publication_date'].str.strip().str[-4:]
dataset1['publication_date'].astype(int)

#import datetime as dt
#dataset1['publication_date'] = pd.to_datetime(dataset1.publication_date)
#dataset1['publication_date'].dt.strftime('%d-%m-%Y')
#dataset1.style.format({"publication_date": lambda t: t.strftime('%d-%m-%Y')})
#dataset1['publication_date'] = pd.to_datetime(dataset1['publication_date'], dayfirst = True)
#dataset1['publication_date'] = pd.to_datetime(dataset1['publication_date'], format='%m/%d/%y')
#dataset1['publication_date'] = pd.DatetimeIndex(dataset1['publication_date']).year

dataset1.head()
# Out:
#    bookID                                              title  \
# 0   44012                       Shield of Thunder (Troy  #2)
# 1    4315                                               Zaat
# 2    2819         A Circle of Quiet (Crosswicks Journals #1)
# 3    4451  People of the Lie: The Hope for Healing Human ...
# 4    5327                                  A Christmas Carol
#
#                                              authors  average_rating  \
# 0                                      David Gemmell            4.36
# 1  Sonallah Ibrahim/صنع الله إبراهيم/Anthony Cald...            3.55
# 2                                  Madeleine L'Engle            4.21
# 3                                      M. Scott Peck            3.98
# 4                         Charles Dickens/P.J. Lynch            4.05
#
#          isbn language_code    num_pages  ratings_count  text_reviews_count  \
# 0   345477014           ale          512            102                  16
# 1  9774248449           ara          349            122                  12
# 2    62545035         en-CA          246           5236                 506
# 3   684848597         en-CA          272           6256                 459
# 4   763631205         en-CA          160           4359                 353
#
#   publication_date                           publisher  Unnamed: 12
# 0             2007                    Ballantine Books          NaN
# 1             2004  American University in Cairo Press          NaN
# 2             1984                           HarperOne          NaN
# 3             1998                          Touchstone          NaN
# 4             2006                    Candlewick Press          NaN

# %%
# Add additional columns (awards and genres)  to first dataset based on isbn
dataset1.shape
dataset2.shape

dataset2 = dataset2[['isbn', 'genre_and_votes', 'awards']]
#dataset = pd.concat([dataset1, dataset2], axis=1, sort=False)

dataset = pd.merge(dataset1, dataset2, on='isbn', how='left')
dataset = dataset.drop('Unnamed: 12', axis = 1)

dataset.shape
dataset.head()
# Out:
#    bookID                                              title  \
# 0   44012                       Shield of Thunder (Troy  #2)
# 1    4315                                               Zaat
# 2    2819         A Circle of Quiet (Crosswicks Journals #1)
# 3    4451  People of the Lie: The Hope for Healing Human ...
# 4    5327                                  A Christmas Carol
#
#                                              authors  average_rating  \
# 0                                      David Gemmell            4.36
# 1  Sonallah Ibrahim/صنع الله إبراهيم/Anthony Cald...            3.55
# 2                                  Madeleine L'Engle            4.21
# 3                                      M. Scott Peck            3.98
# 4                         Charles Dickens/P.J. Lynch            4.05
#
#          isbn language_code    num_pages  ratings_count  text_reviews_count  \
# 0   345477014           ale          512            102                  16
# 1  9774248449           ara          349            122                  12
# 2    62545035         en-CA          246           5236                 506
# 3   684848597         en-CA          272           6256                 459
# 4   763631205         en-CA          160           4359                 353
#
#   publication_date                           publisher genre_and_votes awards
# 0             2007                    Ballantine Books             NaN    NaN
# 1             2004  American University in Cairo Press             NaN    NaN
# 2             1984                           HarperOne             NaN    NaN
# 3             1998                          Touchstone             NaN    NaN
# 4             2006                    Candlewick Press             NaN    NaN

# %%
# Keep only the first author (the others either a translated author name, a translator, etc)
dataset['authors'] = dataset['authors'].str.split('\/').str[1].str.strip()

# %%
# Drop unwanted columns and rows
dataset = dataset.dropna(axis=1, how='all') #drop any column filled only with NaN 
#books = books.drop(['Unnamed: 0'], axis = 1)
dataset = dataset.drop_duplicates()

# %%
# Save the resulted dataframe as csv
dataset.to_csv("~/MISK_DSI/R/DS_Research_GoodreadsBooks/Data/full_books_Python.csv")

# %%
dataset.head()
dataset.shape
# Out:
# (11123, 13)
